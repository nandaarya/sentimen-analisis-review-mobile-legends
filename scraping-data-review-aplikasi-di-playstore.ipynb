# %% [markdown]
# # **Scraping data review aplikasi di Playstore**
#
# # Submission Dicoding
# # Nanda Arya Putra

# %%
# !pip install google-play-scraper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.8 MB/s eta 0:00:00
# ...

# %%
from google_play_scraper import app, reviews, Sort, reviews_all

# %%
# Mengimpor pustaka google_play_scraper untuk mengakses ulasan dan informasi aplikasi dari Google Play Store.
from google_play_scraper import app, reviews_all, Sort

# Mengambil semua ulasan dari aplikasi dengan ID 'com.byu.id' di Google Play Store.
# Proses scraping mungkin memerlukan beberapa saat tergantung pada jumlah ulasan yang ada.
scrapreview = reviews_all(
    'com.mobile.legends',          # ID aplikasi
    lang='id',                     # Bahasa ulasan (default: 'en')
    country='id',                  # Negara (default: 'us')
    sort=Sort.MOST_RELEVANT       # Urutan ulasan (default: Sort.MOST_RELEVANT)
)

# %%
# Menyimpan ulasan dalam file CSV
import csv

with open('ulasan_aplikasi_ml.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Review'])  # Menulis header kolom
    for review in scrapreview:
        writer.writerow([review['content']])  # Menulis konten ulasan ke dalam file CSV

# %%
import pandas as pd

# Membaca file CSV menjadi DataFrame
df = pd.read_csv('ulasan_aplikasi_ml.csv')

# Melihat beberapa baris pertama
print(df.head())

# Melihat informasi umum tentang DataFrame
print(df.info())

# Melihat bentuk DataFrame (jumlah baris dan kolom)
print(df.shape)
# Out:
#                                               Review
# 0  Game dengan matchmaking tersampah yang pernah ...
# 1  game nya bagus, menarik, dan grafik nya juga o...
# 2  Moonton sudah tidak sehat, saat draf pick aman...
# 3  Banyak banget masalahnya dari tim yang berkedo...
# 4  Game nya bagus seru dan menantang juga meskipu...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121500 entries, 0 to 121499
# Data columns (total 1 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Review  121500 non-null  object
# dtypes: object(1)
# memory usage: 949.3+ KB
# None
# (121500, 1)
